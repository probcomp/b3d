# %%
import sys

print(sys.version)
# Out:
# 3.12.7 | packaged by conda-forge | (main, Oct  4 2024, 16:05:46) [GCC 13.3.0]

# %%
import b3d
renderer = b3d.renderer.renderer_original.RendererOriginal()
# Out:
# cuda_home:  /home/haoliangwang/b3d/.pixi/envs/gpu/
# 1st build_directory:  /home/haoliangwang/.cache/torch_extensions/py312_cu120/nvdiffrast_plugin_original_gl
# 2nd build_directory:  /home/haoliangwang/.cache/torch_extensions/py312_cu120/nvdiffrast_plugin_original_gl
# /home/haoliangwang/b3d/.pixi/envs/gpu/lib/python3.12/site-packages/torch/utils/cpp_extension.py:1970: UserWarning: TORCH_CUDA_ARCH_LIST is not set, all archs for visible cards are included for compilation.
# If this is not desired, please set os.environ['TORCH_CUDA_ARCH_LIST'].
#   warnings.warn(
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# File ~/b3d/.pixi/envs/gpu/lib/python3.12/site-packages/torch/utils/cpp_extension.py:2111, in _run_ninja_build(build_directory, verbose, error_prefix)
#    2110     stdout_fileno = 1
# -> 2111     subprocess.run(
#    2112         command,
# ...

# %%
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
