# %%
import json
from os import listdir
from os.path import isfile, join

# %%
first_all = 'gt'
# path = f'/home/haoliangwang/data/b3d_tracking_results/all_scale/{first_all}'
path = f'/home/haoliangwang/data/b3d_tracking_results/test'
scenario = 'drop'
scenario_path = f'{path}/{scenario}'
onlyjson = [
    f
    for f in listdir(scenario_path)
    if isfile(join(scenario_path, f)) and join(scenario_path, f).endswith(".json")
]

# %%
# onlyjson

# %%
configs = set([f[:-10] for f in onlyjson])

# %%
# configs

# %%
for config in configs:
    config_dict = {}
    for f in onlyjson:
        if f[:-10] == config:
            print(f)
            index = int(f[-9:-5])
            f_path = join(scenario_path, f)
            with open(f_path) as f:
                this_trial = json.load(f)
                config_dict[index] = this_trial
    with open(f"{path}/{config}.json", "w") as f:
        json.dump(config_dict, f)
# Out:
# pilot_it2_drop_sidezone_tdw_1_dis_1_occ_0010.json
# pilot_it2_drop_sidezone_tdw_1_dis_1_occ_0012.json
# pilot_it2_drop_sidezone_tdw_1_dis_1_occ_0015.json
# pilot_it2_drop_sidezone_tdw_1_dis_1_occ_0048.json
# pilot_it2_drop_sidezone_tdw_1_dis_1_occ_0007.json
# pilot_it2_drop_sidezone_tdw_1_dis_1_occ_0044.json
# pilot_it2_drop_sidezone_tdw_1_dis_1_occ_0009.json
# pilot_it2_drop_sidezone_tdw_1_dis_1_occ_0006.json
# pilot_it2_drop_sidezone_tdw_1_dis_1_occ_0000.json
# pilot_it2_drop_sidezone_tdw_1_dis_1_occ_0042.json
# pilot_it2_drop_sidezone_tdw_1_dis_1_occ_0017.json
# pilot_it2_drop_sidezone_tdw_1_dis_1_occ_0029.json
# pilot_it2_drop_sidezone_tdw_1_dis_1_occ_0008.json
# pilot_it2_drop_sidezone_tdw_1_dis_1_occ_0030.json
# pilot_it2_drop_sidezone_tdw_1_dis_1_occ_0045.json
# pilot_it2_drop_sidezone_tdw_1_dis_1_occ_0026.json
# pilot_it2_drop_sidezone_tdw_1_dis_1_occ_0005.json
# pilot_it2_drop_sidezone_tdw_1_dis_1_occ_0025.json
# pilot_it2_drop_sidezone_tdw_1_dis_1_occ_0047.json
# pilot_it2_drop_sidezone_tdw_1_dis_1_occ_0014.json
# pilot_it2_drop_sidezone_tdw_1_dis_1_occ_0032.json
# pilot_it2_drop_sidezone_tdw_1_dis_1_occ_0039.json
# pilot_it2_drop_sidezone_tdw_1_dis_1_occ_0036.json
# pilot_it2_drop_sidezone_tdw_1_dis_1_occ_0021.json
# pilot_it2_drop_sidezone_tdw_1_dis_1_occ_0002.json
# pilot_it2_drop_all_bowls_box_0007.json
# pilot_it2_drop_all_bowls_box_0017.json
# pilot_it2_drop_all_bowls_box_0028.json
# pilot_it2_drop_all_bowls_box_0019.json
# pilot_it2_drop_all_bowls_box_0046.json
# pilot_it2_drop_all_bowls_box_0002.json
# pilot_it2_drop_all_bowls_box_0035.json
# pilot_it2_drop_all_bowls_box_0012.json
# pilot_it2_drop_all_bowls_box_0034.json
# pilot_it2_drop_all_bowls_box_0010.json
# pilot_it2_drop_all_bowls_box_0042.json
# pilot_it2_drop_all_bowls_box_0011.json
# pilot_it2_drop_all_bowls_box_0020.json
# pilot_it2_drop_all_bowls_box_0016.json
# pilot_it2_drop_all_bowls_box_0026.json
# pilot_it2_drop_all_bowls_box_0032.json
# pilot_it2_drop_all_bowls_box_0025.json
# pilot_it2_drop_all_bowls_box_0037.json
# pilot_it2_drop_all_bowls_box_0024.json
# pilot_it2_drop_all_bowls_box_0029.json
# pilot_it2_drop_all_bowls_box_0018.json
# pilot_it2_drop_all_bowls_box_0023.json
# pilot_it2_drop_simple_tdw_1_dis_1_occ_0022.json
# pilot_it2_drop_simple_tdw_1_dis_1_occ_0036.json
# pilot_it2_drop_simple_tdw_1_dis_1_occ_0006.json
# pilot_it2_drop_simple_tdw_1_dis_1_occ_0004.json
# pilot_it2_drop_simple_tdw_1_dis_1_occ_0013.json
# pilot_it2_drop_simple_tdw_1_dis_1_occ_0049.json
# pilot_it2_drop_simple_tdw_1_dis_1_occ_0000.json
# pilot_it2_drop_simple_tdw_1_dis_1_occ_0005.json
# pilot_it2_drop_simple_tdw_1_dis_1_occ_0040.json
# pilot_it2_drop_simple_tdw_1_dis_1_occ_0038.json
# pilot_it2_drop_simple_tdw_1_dis_1_occ_0029.json
# pilot_it2_drop_simple_tdw_1_dis_1_occ_0025.json
# pilot_it2_drop_simple_tdw_1_dis_1_occ_0018.json
# pilot_it2_drop_simple_tdw_1_dis_1_occ_0028.json
# pilot_it2_drop_simple_tdw_1_dis_1_occ_0048.json
# pilot_it2_drop_simple_tdw_1_dis_1_occ_0041.json
# pilot_it2_drop_simple_tdw_1_dis_1_occ_0030.json
# pilot_it2_drop_simple_tdw_1_dis_1_occ_0032.json
# pilot_it2_drop_simple_tdw_1_dis_1_occ_0044.json
# pilot_it2_drop_simple_tdw_1_dis_1_occ_0009.json
# pilot_it2_drop_simple_tdw_1_dis_1_occ_0037.json
# pilot_it2_drop_sizes_tdw_1_dis_1_occ_0041.json
# pilot_it2_drop_sizes_tdw_1_dis_1_occ_0016.json
# pilot_it2_drop_sizes_tdw_1_dis_1_occ_0032.json
# pilot_it2_drop_sizes_tdw_1_dis_1_occ_0038.json
# pilot_it2_drop_sizes_tdw_1_dis_1_occ_0010.json
# pilot_it2_drop_sizes_tdw_1_dis_1_occ_0023.json
# pilot_it2_drop_sizes_tdw_1_dis_1_occ_0004.json
# pilot_it2_drop_sizes_tdw_1_dis_1_occ_0007.json
# pilot_it2_drop_sizes_tdw_1_dis_1_occ_0018.json
# pilot_it2_drop_sizes_tdw_1_dis_1_occ_0015.json
# pilot_it2_drop_sizes_tdw_1_dis_1_occ_0022.json
# pilot_it2_drop_sizes_tdw_1_dis_1_occ_0033.json
# pilot_it2_drop_sizes_tdw_1_dis_1_occ_0021.json
# pilot_it2_drop_sidezone_box_0020.json
# pilot_it2_drop_sidezone_box_0047.json
# pilot_it2_drop_sidezone_box_0042.json
# pilot_it2_drop_sidezone_box_0034.json
# pilot_it2_drop_sidezone_box_0019.json
# pilot_it2_drop_sidezone_box_0048.json
# pilot_it2_drop_sidezone_box_0021.json
# pilot_it2_drop_sidezone_box_0046.json
# pilot_it2_drop_sidezone_box_0035.json
# pilot_it2_drop_sidezone_box_0032.json
# pilot_it2_drop_sidezone_box_0003.json
# pilot_it2_drop_sidezone_box_0018.json
# pilot_it2_drop_sidezone_box_0011.json
# pilot_it2_drop_sidezone_box_0024.json
# pilot_it2_drop_sidezone_box_0015.json
# pilot_it2_drop_sidezone_box_0043.json
# pilot_it2_drop_sidezone_box_0004.json
# pilot_it2_drop_sidezone_box_0022.json
# pilot_it2_drop_sidezone_box_0044.json
# pilot_it2_drop_sidezone_box_0037.json
# pilot_it2_drop_sizes_box_0010.json
# pilot_it2_drop_sizes_box_0024.json
# pilot_it2_drop_sizes_box_0045.json
# pilot_it2_drop_sizes_box_0009.json
# pilot_it2_drop_sizes_box_0014.json
# pilot_it2_drop_sizes_box_0003.json
# pilot_it2_drop_sizes_box_0011.json
# pilot_it2_drop_sizes_box_0029.json
# pilot_it2_drop_sizes_box_0019.json
# pilot_it2_drop_sizes_box_0049.json
# pilot_it2_drop_sizes_box_0026.json
# pilot_it2_drop_sizes_box_0030.json
# pilot_it2_drop_sizes_box_0036.json
# pilot_it2_drop_sizes_box_0017.json
# pilot_it2_drop_sizes_box_0021.json
# pilot_it2_drop_sizes_box_0041.json
# pilot_it2_drop_sizes_box_0008.json
# pilot_it2_drop_sizes_box_0042.json
# pilot_it2_drop_simple_box_0034.json
# pilot_it2_drop_simple_box_0029.json
# pilot_it2_drop_simple_box_0007.json
# pilot_it2_drop_simple_box_0033.json
# pilot_it2_drop_simple_box_0016.json
# pilot_it2_drop_simple_box_0026.json
# pilot_it2_drop_simple_box_0028.json
# pilot_it2_drop_simple_box_0040.json
# pilot_it2_drop_simple_box_0019.json
# pilot_it2_drop_simple_box_0035.json
# pilot_it2_drop_simple_box_0003.json
# pilot_it2_drop_simple_box_0015.json
# pilot_it2_drop_simple_box_0008.json
# pilot_it2_drop_simple_box_0032.json
# pilot_it2_drop_simple_box_0020.json
# pilot_it2_drop_simple_box_0047.json
# pilot_it2_drop_simple_box_0027.json
# pilot_it2_drop_simple_box_0005.json
# pilot_it2_drop_simple_box_0017.json
# pilot_it2_drop_simple_box_0010.json
# pilot_it2_drop_all_bowls_tdw_1_dis_1_occ_0013.json
# pilot_it2_drop_all_bowls_tdw_1_dis_1_occ_0008.json
# pilot_it2_drop_all_bowls_tdw_1_dis_1_occ_0002.json
# pilot_it2_drop_all_bowls_tdw_1_dis_1_occ_0003.json
# pilot_it2_drop_all_bowls_tdw_1_dis_1_occ_0046.json
# pilot_it2_drop_all_bowls_tdw_1_dis_1_occ_0049.json
# pilot_it2_drop_all_bowls_tdw_1_dis_1_occ_0004.json
# pilot_it2_drop_all_bowls_tdw_1_dis_1_occ_0007.json
# pilot_it2_drop_all_bowls_tdw_1_dis_1_occ_0027.json
# pilot_it2_drop_all_bowls_tdw_1_dis_1_occ_0026.json
# pilot_it2_drop_all_bowls_tdw_1_dis_1_occ_0025.json
# pilot_it2_drop_all_bowls_tdw_1_dis_1_occ_0047.json
# pilot_it2_drop_all_bowls_tdw_1_dis_1_occ_0018.json
# pilot_it2_drop_all_bowls_tdw_1_dis_1_occ_0029.json
# pilot_it2_drop_all_bowls_tdw_1_dis_1_occ_0040.json
# pilot_it2_drop_all_bowls_tdw_1_dis_1_occ_0016.json
