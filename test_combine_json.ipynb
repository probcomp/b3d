# %%
import json
from os import listdir
from os.path import isfile, join

# %%
first_all = 'gt'
# path = f'/home/haoliangwang/data/b3d_tracking_results/all_scale/{first_all}'
path = f'/home/haoliangwang/data/b3d_tracking_results/test'
scenario = 'contain'
scenario_path = f'{path}/{scenario}'
onlyjson = [
    f
    for f in listdir(scenario_path)
    if isfile(join(scenario_path, f)) and join(scenario_path, f).endswith(".json")
]

# %%
# onlyjson

# %%
configs = set([f[:-10] for f in onlyjson])

# %%
# configs

# %%
for config in configs:
    config_dict = {}
    for f in onlyjson:
        if f[:-10] == config:
            print(f)
            index = int(f[-9:-5])
            f_path = join(scenario_path, f)
            with open(f_path) as f:
                this_trial = json.load(f)
                config_dict[index] = this_trial
    with open(f"{path}/{config}.json", "w") as f:
        json.dump(config_dict, f)
# Out:
# pilot-containment-vase_torus_0032.json
# pilot-containment-vase_torus_0042.json
# pilot-containment-vase_torus_0005.json
# pilot-containment-vase_torus_0046.json
# pilot-containment-vase_torus_0002.json
# pilot-containment-vase_torus_0023.json
# pilot-containment-vase_torus_0033.json
# pilot-containment-vase_torus_0047.json
# pilot-containment-vase_torus_0028.json
# pilot-containment-vase_torus_0045.json
# pilot-containment-vase_torus_0024.json
# pilot-containment-vase_torus_0037.json
# pilot-containment-vase_torus_0000.json
# pilot-containment-vase_torus_0029.json
# pilot-containment-vase_torus_0043.json
# pilot-containment-vase_torus_0009.json
# pilot-containment-cylinder-bowl_0028.json
# pilot-containment-cylinder-bowl_0011.json
# pilot-containment-cylinder-bowl_0026.json
# pilot-containment-cylinder-bowl_0021.json
# pilot-containment-cylinder-bowl_0022.json
# pilot-containment-cylinder-bowl_0029.json
# pilot-containment-cylinder-bowl_0042.json
# pilot-containment-cylinder-bowl_0023.json
# pilot-containment-cylinder-bowl_0043.json
# pilot-containment-cylinder-bowl_0045.json
# pilot-containment-cylinder-bowl_0033.json
# pilot-containment-cylinder-bowl_0010.json
# pilot-containment-cylinder-bowl_0027.json
# pilot-containment-cylinder-bowl_0009.json
# pilot-containment-cylinder-bowl_0032.json
# pilot-containment-cylinder-bowl_0018.json
# pilot-containment-cylinder-bowl_0046.json
# pilot-containment-cylinder-bowl_0035.json
# pilot-containment-cylinder-bowl_0006.json
# pilot-containment-cylinder-bowl_0030.json
# pilot-containment-torus_0000.json
# pilot-containment-torus_0040.json
# pilot-containment-torus_0009.json
# pilot-containment-torus_0011.json
# pilot-containment-torus_0035.json
# pilot-containment-torus_0030.json
# pilot-containment-torus_0020.json
# pilot-containment-torus_0026.json
# pilot-containment-torus_0017.json
# pilot-containment-torus_0010.json
# pilot-containment-torus_0037.json
# pilot-containment-torus_0004.json
# pilot-containment-torus_0014.json
# pilot-containment-torus_0042.json
# pilot-containment-torus_0022.json
# pilot-containment-torus_0046.json
# pilot-containment-torus_0013.json
# pilot-containment-torus_0043.json
# pilot-containment-torus_0048.json
# pilot-containment-torus_0044.json
# pilot-containment-bowl-familiarization_0024.json
# pilot-containment-bowl-familiarization_0033.json
# pilot-containment-bowl-familiarization_0010.json
# pilot-containment-bowl-familiarization_0018.json
