# %%
import numpy as np
import h5py

# %%
hdf5_file_path = '/home/haoliangwang/data/physion_hdf5/collide_all_movies/pilot_it2_collision_assorted_targets_box_0003.hdf5'
vels = []
ang_vels = []
with h5py.File(hdf5_file_path, "r") as f:
    for frame in f["frames"].keys():
        vel = np.array(f["frames"][frame]["objects"]["velocities"])
        vels.append(vel)
        ang_vel = np.array(f["frames"][frame]["objects"]["angular_velocities"])
        ang_vels.append(ang_vel)

# %%
vels
# Out:
# [array([[ 0.0000000e+00,  0.0000000e+00,  0.0000000e+00],
#         [-1.6995418e-07,  8.1956387e-08,  3.1076615e-07],
#         [-3.5938905e-05, -1.4901161e-08,  5.1811671e-06]], dtype=float32),
#  array([[ 0.0000000e+00,  0.0000000e+00,  0.0000000e+00],
#         [-3.3410615e-08,  1.4901161e-08,  6.1538060e-08],
#         [ 5.9045925e+00,  2.8189719e-03,  6.5133959e-01]], dtype=float32),
#  array([[ 0.0000000e+00,  0.0000000e+00,  0.0000000e+00],
#         [-9.7516661e-10,  0.0000000e+00, -8.3417007e-10],
#         [ 5.6839514e+00,  7.9130727e-01,  6.2700063e-01]], dtype=float32),
#  array([[ 0.0000000e+00,  0.0000000e+00,  0.0000000e+00],
#         [-3.0056069e-09,  0.0000000e+00, -1.5995583e-10],
#         [ 5.6839514e+00,  6.9320726e-01,  6.2700063e-01]], dtype=float32),
#  array([[ 0.0000000e+00,  0.0000000e+00,  0.0000000e+00],
#         [ 4.6180992e-10,  0.0000000e+00, -1.4799947e-09],
#         [ 5.6839514e+00,  5.9510726e-01,  6.2700063e-01]], dtype=float32),
# ...

# %%
ang_vels
# Out:
# [array([[0.0000000e+00, 0.0000000e+00, 0.0000000e+00],
#         [4.2531838e-06, 5.7983780e-08, 2.0407199e-06],
#         [3.0775871e-05, 1.7930892e-05, 2.1054914e-04]], dtype=float32),
#  array([[ 0.0000000e+00,  0.0000000e+00,  0.0000000e+00],
#         [ 8.4150611e-07,  1.2330833e-08,  3.9840700e-07],
#         [ 3.5345044e+00,  1.3268378e+01, -3.2104214e+01]], dtype=float32),
#  array([[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [-1.22724373e-08,  6.38069109e-09,  1.48921515e-08],
#         [ 4.83813286e+00,  9.97152996e+00, -3.22080002e+01]], dtype=float32),
#  array([[ 0.0000000e+00,  0.0000000e+00,  0.0000000e+00],
#         [-9.2977261e-09,  2.5644331e-10,  4.3716604e-08],
#         [ 4.8381329e+00,  9.9715300e+00, -3.2208000e+01]], dtype=float32),
#  array([[ 0.0000000e+00,  0.0000000e+00,  0.0000000e+00],
#         [-2.3460773e-08,  2.5511526e-10, -7.2166060e-09],
#         [ 4.8381329e+00,  9.9715300e+00, -3.2208000e+01]], dtype=float32),
# ...

# %%
# Update position
body.position += body.velocity * dt

# Update orientation quaternion
omega = body.angular_velocity
omega_quat = Quaternions.Quaternion(0.0, omega[1], omega[2], omega[3])
body.orientation += 0.5 * omega_quat * body.orientation * dt
body.orientation = normalize(body.orientation)
